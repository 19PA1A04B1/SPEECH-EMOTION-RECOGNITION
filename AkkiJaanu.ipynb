# %%
pip install librosa soundfile numpy sklearn pyaudio
# Out:
# Requirement already satisfied: librosa in c:\users\lenovo\anaconda3\lib\site-packages (0.9.2)
# Requirement already satisfied: soundfile in c:\users\lenovo\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (1.23.5)
# Requirement already satisfied: sklearn in c:\users\lenovo\anaconda3\lib\site-packages (0.0.post1)
# Collecting pyaudio
#   Downloading PyAudio-0.2.13-cp39-cp39-win_amd64.whl (164 kB)
#      -------------------------------------- 164.1/164.1 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (0.4.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (1.7.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (23.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: numba>=0.45.1 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: joblib>=0.14 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from librosa) (1.9.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (67.6.1)
# Collecting numpy
#   Downloading numpy-1.21.6-cp39-cp39-win_amd64.whl (14.0 MB)
#      ---------------------------------------- 14.0/14.0 MB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\lenovo\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Installing collected packages: pyaudio, numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\lenovo\\anaconda3\\Lib\\site-packages\\~umpy\\.libs\\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.

# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
#DataFlair - Extract features (mfcc, chroma, mel) from a sound file
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
    return result

# %%
#DataFlair - Emotions in the RAVDESS dataset
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
observed_emotions=['calm', 'happy', 'fearful', 'disgust']

# %%
#DataFlair - Load the data and extract features for each sound file
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("Downloads\\data\\Actor_*\\*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
#DataFlair - Split the dataset
x_train,x_test,y_train,y_test=load_data(test_size=0.25)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 3.0517578e-05 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -3.0517578e-05
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 3.0517578e-05 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[1.5258789e-04 1.5258789e-04 9.1552734e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.00091553 -0.00091553 -0.00097656 ... -0.0017395  -0.0017395
#  -0.0017395 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[5.1879883e-04 2.4414062e-04 1.5258789e-04 ... 0.0000000e+00 0.0000000e+00
#  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-9.1552734e-05 -1.2207031e-04 -6.1035156e-05 ...  1.0986328e-03
#   3.3569336e-04 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[2.5726318e-02 3.1707764e-02 3.5552979e-02 ... 0.0000000e+00 3.0517578e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00039673 -0.00012207
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-1.0375977e-03 -7.9345703e-04 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[3.0517578e-05 2.7465820e-04 5.1879883e-04 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 0.0000000e+00
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -1.2207031e-04 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#  -6.1035156e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.1035156e-05 6.1035156e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 3.0517578e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#  -3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 9.1552734e-05 1.2207031e-04
#  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 1.8310547e-04 6.1035156e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.         0.         0.00015259 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.         -0.00012207 -0.00027466 ... -0.00015259 -0.00015259
#  -0.00021362] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.         0.00015259 0.00015259 ... 0.00024414 0.00024414 0.00018311] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 6.1035156e-05  6.1035156e-05  9.1552734e-05 ... -3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 5.1879883e-04 -6.1035156e-05 -4.2724609e-04 ...  0.0000000e+00
#  -9.1552734e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 1.2207031e-04  1.5258789e-04 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.00027466 -0.00024414 -0.00027466 ... -0.00015259 -0.00021362
#  -0.00024414] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-9.1552734e-05 -9.1552734e-04 -1.0986328e-03 ...  2.7465820e-04
#   3.0517578e-04  3.6621094e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00021362 -0.00033569
#  -0.00042725] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 3.0517578e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -1.5258789e-04
#  -1.5258789e-04 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0005188  -0.0005188
#  -0.00054932] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.00018311  0.00018311  0.00018311 ...  0.00027466  0.00021362
#  -0.00061035] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.01373291 -0.01370239 -0.01379395 ... -0.00057983 -0.00180054
#  -0.00396729] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.00033569 -0.00045776 -0.00042725 ... -0.00082397 -0.00082397
#  -0.00061035] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.00210571 -0.00375366 -0.00332642 ... -0.00073242 -0.0007019
#  -0.00057983] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-1
0.00021362 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 1.2207031e-04  9.1552734e-05  9.1552734e-05 ...  0.0000000e+00
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00015259 -0.00015259
#  -0.00012207] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00024414 -0.00024414
#  -0.00021362] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  3.0517578e-05
#   3.0517578e-05  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -9.1552734e-05
#  -1.2207031e-04 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-6.1035156e-05 -3.0517578e-05 -6.1035156e-05 ... -2.4414062e-04
#  -2.4414062e-04 -2.4414062e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.         0.         0.         ... 0.00308228 0.00311279 0.00308228] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[3.0517578e-05 6.1035156e-05 0.0000000e+00 ... 9.1552734e-05 6.1035156e-05
#  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-1.2207031e-04 -1.2207031e-04 -1.2207031e-04 ...  9.1552734e-05
#   9.1552734e-05  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.00036621  0.00045776  0.00048828 ... -0.00021362 -0.00021362
#  -0.00021362] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.00067139  0.00076294  0.00106812 ...  0.00344849 -0.00195312
#  -0.00204468] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-1.2207031e-04 -1.2207031e-04 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -1.8310547e-04
#  -1.8310547e-04 -1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-9.1552734e-05 -9.1552734e-05 -6.1035156e-05 ... -6.7138672e-04
#  -7.6293945e-04 -7.3242188e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.         0.         0.         ... 0.00018311 0.00024414 0.00024414] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  2.4414062e-04
#   2.1362305e-04  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 3.0517578e-05 ... 9.1552734e-05 1.2207031e-04
#  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.00082397 -0.00079346 -0.0007019  ... -0.00094604 -0.00061035
#  -0.00076294] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.         0.         0.         ... 0.00018311 0.00015259 0.00018311] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 9.1552734e-05  9.1552734e-05  9.1552734e-05 ... -9.1552734e-05
#  -9.1552734e-05 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.00012207 0.00012207 0.00012207 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05  9.1552734e-05 ...  1.0070801e-03
#   1.1901855e-03  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05 -3.0517578e-05 ... -8.5449219e-04
#  -8.5449219e-04 -8.5449219e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 3.0517578e-05 9.1552734e-05 ... 1.2207031e-04 1.5258789e-04
#  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#   3.0517578e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.00091553 -0.00115967  0.0012207  ... -0.00064087  0.00033569
#  -0.00048828] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[-0.00177002 -0.00064087  0.00164795 ...  0.00042725  0.00170898
#   0.00057983] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 6.1035156e-05 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 5.4931641e-04  1.1901855e-03  5.4931641e-04 ...  3.0517578e-05
#  -1.4343262e-03 -8.5449219e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -2.4414062e-04
#  -1.2207031e-04 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[3.0517578e-05 0.0000000e+00 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00057983 -0.00054932
#  -0.00057983] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ...  3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.1035156e-05 9.1552734e-05
#  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[0.         0.         0.         ... 0.00024414 0.00024414 0.00024414] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19372\399116557.py:16: FutureWarning: Pass y=[ 0.0000000e+00 -6.1035156e-05 -6.1035156e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)

# %%
print((x_train.shape[0], x_test.shape[0]))
# Out:
# (576, 192)

# %%
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# Features extracted: 180

# %%
#DataFlair - Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %%
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
y_pred=model.predict(x_test)

# %%
#DataFlair - Calculate the accuracy of our model
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)

#DataFlair - Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 74.48%

# %%
import pandas as pd
av_pv=pd.DataFrame({"prdicted":y_pred,"actual":y_test})
av_pv.head(50)

#print(y_test)
#print(y_pred)
# Out:
#    prdicted   actual
# 0     happy    happy
# 1      calm     calm
# 2     happy    happy
# 3     happy    happy
# 4   disgust  disgust
# 5      calm     calm
# 6     happy    happy
# 7   disgust    happy
# 8      calm  disgust
# 9     happy    happy
# 10    happy    happy
# 11  fearful  disgust
# 12  fearful    happy
# 13    happy    happy
# 14  disgust  disgust
# 15    happy  fearful
# 16     calm     calm
# 17  disgust    happy
# 18  disgust  disgust
# 19     calm  disgust
# 20  disgust     calm
# 21  disgust  disgust
# 22  disgust  disgust
# 23     calm     calm
# 24    happy    happy
# 25    happy    happy
# 26     calm  disgust
# 27    happy  disgust
# 28     calm     calm
# 29  fearful     calm
# 30    happy    happy
# 31    happy  disgust
# 32    happy    happy
# 33     calm  fearful
# 34    happy  fearful
# 35     calm     calm
# 36     calm     calm
# 37  fearful  fearful
# 38     calm     calm
# 39  disgust     calm
# 40    happy    happy
# 41     calm  disgust
# 42     calm     calm
# 43     calm     calm
# 44    happy  disgust
# 45     calm     calm
# 46  disgust  disgust
# 47    happy    happy
# 48     calm     calm
# 49    happy    happy
